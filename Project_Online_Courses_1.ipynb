# %%
dict1 = {

    "Course1": {
        "Name": "Java",
        "Teacher": "Sara Ahmed",
        "Price": 250,
        "bachelor's required": False,
    },
    
    "Course2": {
        "Name": "Python",
        "Teacher": "Laila Khalid",
        "Price": 500,
        "bachelor's required": False,
    },
    
    "Course3": {
        "Name": "Dart",
        "Teacher": "Mohammed Ali",
        "Price": 450,
        "bachelor's required": True
        ,
    },
    
    "Course4": {
        "Name": "UX Design",
        "Teacher": "Razan Fahad",
        "Price": 150,
        "bachelor's required": False,
    },
    
    "Course5": {
        "Name": "JavaScript",
        "Teacher": "Sara Mohammed",
        "Price": 300,
        "bachelor's required": True,
    },
    
    "Course6": {
        "Name": "Web Development",
        "Teacher": "Hesssa Khalid",
        "Price": 100,
        "bachelor's required": True,
    },
    
     "Course7": {
        "Name": "Android Development",
        "Teacher": "Nora ",
        "Price": 250,
        "bachelor's required": False,
    },
    
    "Course8": {
        "Name": "IOS Development",
        "Teacher": "Reem Hassan",
        "Price": 370,
        "bachelor's required": False,
    },
    
    "Course9": {
        "Name": "Data Science",
        "Teacher": "Rehab Abdullah",
        "Price": 400,
        "bachelor's required": True,
    },
    
    "Course10": {
        "Name": "MySql",
        "Teacher": "Rehab Abdullah",
        "Price": 100,
        "bachelor's required": False,
    },
 
}

#print(dict1)


###############Function#############
 
def TeacherName(TeacherN,diroc): # Parameters
    mylist1=[]
    for d in diroc.values():        
        if d['Teacher'] == TeacherN:
            if d['bachelor\'s required']== False:
                xx="No"
            if d['bachelor\'s required']== True:
                xx="Yes"
           
            mylist1.append("Course: "+d['Name']+"|"+"Teacher: "+d['Teacher']+"|"+"Cost: "+str(d['Price'])+"|"+"bachelor\'s required: "+xx)    
    return mylist1
            
       
           
    return print("Sorry, courses of",TeacherN," is not found")
  

def ListOfCourses(diroc): # Parameters
    mylist=[]
    for d in diroc.values():
        if d['bachelor\'s required']== False:
            x="No"
        if d['bachelor\'s required']== True:
            x="Yes"
           
        mylist.append("Course: "+d['Name']+"|"+"Teacher: "+d['Teacher']+"|"+"Cost: "+str(d['Price'])+"|"+"bachelor\'s required: "+x)    
    return mylist
            
       
        
               
###############Input#############

for s in ListOfCourses(dict1):
    print(s)  
    print("\n")  

UserInput=input("Teacher name you want to enroll with ?")            
 
for z in TeacherName(UserInput,dict1):
    print(z)  
    print("\n")
#print(TeacherName(UserInput,dict1))
# Out:
# Course: Java|Teacher: Sara Ahmed|Cost: 250|bachelor's required: No
#
#
# Course: Python|Teacher: Laila Khalid|Cost: 500|bachelor's required: No
#
#
# Course: Dart|Teacher: Mohammed Ali|Cost: 450|bachelor's required: Yes
#
#
# Course: UX Design|Teacher: Razan Fahad|Cost: 150|bachelor's required: No
#
#
# Course: JavaScript|Teacher: Sara Mohammed|Cost: 300|bachelor's required: Yes
#
#
# Course: Web Development|Teacher: Hesssa Khalid|Cost: 100|bachelor's required: Yes
#
#
# Course: Android Development|Teacher: Nora |Cost: 250|bachelor's required: No
#
#
# Course: IOS Development|Teacher: Reem Hassan|Cost: 370|bachelor's required: No
#
#
# Course: Data Science|Teacher: Rehab Abdullah|Cost: 400|bachelor's required: Yes
#
#
# Course: MySql|Teacher: Rehab Abdullah|Cost: 100|bachelor's required: No
#
#
# Teacher name you want to enroll with ?Sara Mohammed
# Course: JavaScript|Teacher: Sara Mohammed|Cost: 300|bachelor's required: Yes
